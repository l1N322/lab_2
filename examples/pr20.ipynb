# %%
import numpy as np
m_e = [[1, 0, 0], [0, 1, 0], [0, 0, 1]]
m_e_np = np.matrix(m_e)
print(m_e_np)
# Out:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]

# %%
m_eye = np.eye(3)
print(m_eye)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
m_zeros = np.zeros((3, 3))
print(m_zeros)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
