# %% [markdown]
# # Задание 1

# %% [markdown]
# ### Создайте массив NumPy размером 3×3, содержащий числа от 1 до 9. Умножьте все элементы массива на 2, а затем замените все элементы больше 10 на 0. Выведите итоговый массив.

# %%
import numpy as np

arr = np.arange(1, 10).reshape(3,3)
arr *= 2
arr[arr > 10] = 0
print(arr)
# Out:
# [[ 2  4  6]
#  [ 8 10  0]
#  [ 0  0  0]]

# %% [markdown]
# # Задание 2

# %% [markdown]
# ### Создайте массив NumPy из 20 случайных целых чисел от 1 до 100. Найдите и выведите все элементы, которые делятся на 5 без остатка. Затем замените их на -1 и выведите обновленный массив.

# %%
import numpy as np

arr = np.random.randint(1, 101, size=20)
print(f"Исходный массив: {arr}")
divide_by_5 = arr[arr % 5 == 0]
print(f"Элементы массива, которые делятся на 5 без остатка: {divide_by_5}")
arr[arr % 5 == 0] = -1
print(f"Обновленный массив: {arr}")
# Out:
# Исходный массив: [99 64 50 50 84 50 73 54 79 39 73 22 76 48 24 88 92 55  2  8]
# Элементы массива, которые делятся на 5 без остатка: [50 50 50 55]
# Обновленный массив: [99 64 -1 -1 84 -1 73 54 79 39 73 22 76 48 24 88 92 -1  2  8]

# %% [markdown]
# # Задание 3

# %% [markdown]
# ### Создайте два массива NumPy размером 1×5, заполненные случайными числами от 0 до 50. Объедините эти массивы в один двумерный массив (по строкам). Разделите полученный массив на два массива, каждый из которых содержит 5 элементов. Выведите все промежуточные и итоговые результаты.

# %%
import numpy as np

arr1 = np.random.randint(0, 51, size=(1, 5))
arr2 = np.random.randint(0, 51, size=(1, 5))

print("Первый массив:", arr1)
print("Второй массив:", arr2)

combined = np.vstack((arr1, arr2))
print("Объединённый двумерный массив:\n", combined)

split1, split2 = np.vsplit(combined, 2)
print("Первый разделённый массив:", split1)
print("Второй разделённый массив:", split2)
# Out:
# Первый массив: [[23 24 36 23 37]]
# Второй массив: [[21 25 13  3 47]]
# Объединённый двумерный массив:
#  [[23 24 36 23 37]
#  [21 25 13  3 47]]
# Первый разделённый массив: [[23 24 36 23 37]]
# Второй разделённый массив: [[21 25 13  3 47]]

# %% [markdown]
# # Задание 4

# %% [markdown]
# ### Создайте массив из 50 чисел, равномерно распределенных от -10 до 10. Вычислите сумму всех элементов, сумму положительных элементов и сумму отрицательных элементов. Выведите результаты.

# %%
import numpy as np

arr = np.linspace(-10, 10, 50)
print(arr)

arr_sum = np.sum(arr)
positive_sum = np.sum(arr[arr > 0])
negative_sum = np.sum(arr[arr < 0])

print("\nСумма всех элементов:", arr_sum)
print("Сумма положительных элементов:", positive_sum)
print("Сумма отрицательных элементов:", negative_sum)
# Out:
# [-10.          -9.59183673  -9.18367347  -8.7755102   -8.36734694
#   -7.95918367  -7.55102041  -7.14285714  -6.73469388  -6.32653061
#   -5.91836735  -5.51020408  -5.10204082  -4.69387755  -4.28571429
#   -3.87755102  -3.46938776  -3.06122449  -2.65306122  -2.24489796
#   -1.83673469  -1.42857143  -1.02040816  -0.6122449   -0.20408163
#    0.20408163   0.6122449    1.02040816   1.42857143   1.83673469
#    2.24489796   2.65306122   3.06122449   3.46938776   3.87755102
#    4.28571429   4.69387755   5.10204082   5.51020408   5.91836735
#    6.32653061   6.73469388   7.14285714   7.55102041   7.95918367
#    8.36734694   8.7755102    9.18367347   9.59183673  10.        ]
#
# Сумма всех элементов: 7.105427357601002e-15
# Сумма положительных элементов: 127.55102040816328
# Сумма отрицательных элементов: -127.55102040816327

# %% [markdown]
# # Задание 5

# %% [markdown]
# ### Создайте: Единичную матрицу размером 4×4. Диагональную матрицу размером 4×4 с диагональными элементами [5, 10, 15, 20] (не использовать циклы). Найдите сумму всех элементов каждой из этих матриц и сравните результаты.

# %%
import numpy as np

idnt = np.eye(4)
diag = np.diag([5, 10, 15, 20])

sum_idnt = np.sum(idnt)
sum_diag = np.sum(diag)

print("Сумма элементов единичной матрицы:", sum_idnt)
print("Сумма элементов диагональной матрицы:", sum_diag)

if sum_idnt > sum_diag:
    print("Сумма элементов единичной матрицы больше")
elif sum_idnt < sum_diag:
    print("Сумма элементов диагональной матрицы больше")
else:
    print("Суммы равны")
# Out:
# Сумма элементов единичной матрицы: 4.0
# Сумма элементов диагональной матрицы: 50
# Сумма элементов диагональной матрицы больше

# %% [markdown]
# # Задание 6

# %% [markdown]
# ### Создайте две квадратные матрицы NumPy размером 3×3, заполненные случайными целыми числами от 1 до 20. Вычислите и выведите: Их сумму, их разность, их поэлементное произведение.

# %%
import numpy as np

A1 = np.random.randint(1, 21, size=(3, 3))
A2 = np.random.randint(1, 21, size=(3, 3))

print("Матрица 1:\n", A1)
print("Матрица 2:\n", A2)

print("Сумма:\n", A1 + A2)
print("Разность:\n", A1 - A2)
print("Поэлементное произведение:\n", A1 * A2)
# Out:
# Матрица 1:
#  [[ 1  1 13]
#  [20 18  6]
#  [15  9 15]]
# Матрица 2:
#  [[14  7 20]
#  [19 18  5]
#  [ 5  7  3]]
# Сумма:
#  [[15  8 33]
#  [39 36 11]
#  [20 16 18]]
# Разность:
#  [[-13  -6  -7]
#  [  1   0   1]
#  [ 10   2  12]]
# Поэлементное произведение:
#  [[ 14   7 260]
#  [380 324  30]
#  [ 75  63  45]]

# %% [markdown]
# # Задание 7

# %% [markdown]
# ### Создайте две матрицы NumPy: Первую размером 2×3, заполненную случайными числами от 1 до 10. Вторую размером 3×2, заполненную случайными числами от 1 до 10. Выполните матричное умножение (@ или nр. dot ) и выведите результат.

# %%
import numpy as np

A = np.random.randint(1, 11, size=(2, 3))
B = np.random.randint(1, 11, size=(3, 2))
print("Первая матрица:\n", A)
print("Вторая матрица:\n", B)

result = np.dot(A, B)

print("Результат матричного умножения\n", result)
# Out:
# Первая матрица:
#  [[ 6  1  8]
#  [ 4 10  7]]
# Вторая матрица:
#  [[8 5]
#  [9 1]
#  [7 3]]
# Результат матричного умножения
#  [[113  55]
#  [171  51]]

# %% [markdown]
# # Задание 8

# %% [markdown]
# ### Создайте случайную квадратную матрицу 3×3. Найдите и выведите: Определитель этой матрицы, Обратную матрицу (если существует, иначе выведите сообщение, что матрица вырождена). Используйте функции np.linalg.det и nр.linalg.inv.

# %%
import numpy as np

A = np.random.rand(3, 3)
print("Случайная матрица:\n", A)

A_det = round(np.linalg.det(A), 3)
print("\nОпределитель матрицы", A_det)

if A_det == 0:
    print("\nМатрица вырождена!")
else:
    A_inv = np.linalg.inv(A)
    print("\nОбратная матрица:\n", A_inv)
# Out:
# Случайная матрица:
#  [[0.1091962  0.50778792 0.16776077]
#  [0.40753372 0.94025445 0.87952302]
#  [0.90809258 0.56816565 0.76534638]]
#
# Определитель матрицы 0.167
#
# Обратная матрица:
#  [[ 1.31838081 -1.75850242  1.73185739]
#  [ 2.91837314 -0.41228715 -0.16590198]
#  [-3.73076989  2.39255121 -0.62511179]]

# %% [markdown]
# # Задание 9

# %% [markdown]
# ### Создайте матрицу NumPy размером 4×4, содержащую случайные целые числа от 1 до 50. Выведите: Исходную матрицу, Транспонированную матрицу, След матрицы (сумму элементов на главной диагонали). Используйте np.trace для нахождения следа.

# %%
import numpy as np

A = np.random.randint(1, 51, size = (4, 4))
A_t = np.transpose(A)
A_trace = np.trace(A)

print("Исходная матрица:\n", A)
print("Транспонированная матрица:\n", A_t)
print("След матрицы:\n", A_trace)
# Out:
# Исходная матрица:
#  [[15 48 42 31]
#  [ 7 42 42 38]
#  [ 8 50 46 32]
#  [21 37 41  3]]
# Транспонированная матрица:
#  [[15  7  8 21]
#  [48 42 50 37]
#  [42 42 46 41]
#  [31 38 32  3]]
# След матрицы:
#  106

# %% [markdown]
# # Задание 10

# %% [markdown]
# ### Решите систему линейных уравнений вида:
# $2x + 3y - z = 5$<br>
# $4x - y + 2z = 6$<br>
# $-3x + 5y + 4z = -2$

# %%
import numpy as np

A = np.array([[2, 3, -1],
              [4, -1, 2],
              [-3, 5, 4]])

B = np.array([5, 6, -2])

x = np.linalg.solve(A, B)
print("Решение системы (x, y, z):", x)
# Out:
# Решение системы (x, y, z): [1.63963964 0.57657658 0.00900901]

# %% [markdown]
# # Индивидуальное задание

# %% [markdown]
# ### Задание предусматривает построение системы линейных уравнений. Решите полученную систему уравнений с использованием библиотеки NumPy. Для решения системы используйте метод Крамера и матричный метод. Сравните полученные результаты, с результатами, полученными с помощью np.linalg.solve.

# %% [markdown]
# ### **Условие**: Распределение электроэнергии. Город получает электроэнергию от трех электростанций. Первая станция дает в два раза больше энергии, чем вторая, а третья - на 200 МВт больше, чем вторая. Всего требуется 1500 МВт. Сколько электроэнергии должно поступать с каждой станции?

# %% [markdown]
# ### **Решение**: Пусть x1, x2, x3 - мощности (МВт) первой, второй, третьей станций соответственно.
# $x1 = x2 * 2$ <br>
# $x3 = x2 + 200$ <br>
# $x1 + x2 + x3 = 1500$ <br>
# ### Получаем систему уравнений:
# $x1 – x2 * 2 = 0$ <br>
# $x3 – x2 = 200$ <br>
# $x1 + x2 + x3 = 1500$ <br>

# %%
import numpy as np

A = np.array([
    [1, -2, 0],
    [0, -1, 1],
    [1, 1, 1]
])
B = np.array([0, 200, 1500])

A_det = np.linalg.det(A)
if A_det == 0:
    print("Матрица вырождена, метод Крамера неприменим.")
else:
    x_cramer = []
    for i in range(3):
        Ai = A.copy()
        Ai[:, i] = B
        Ai_det = np.linalg.det(Ai)
        x_cramer.append(Ai_det / A_det)
    x_cramer = np.array(x_cramer)
    print("Метод Крамера:", x_cramer)

if A_det == 0:
    print("Матрица вырождена, обратная матрица не существует.")
else:
    A_inv = np.linalg.inv(A)
    x_inv = np.dot(A_inv, B)
    print("Матричный метод:", x_inv)

x_solve = np.linalg.solve(A, B)
print("np.linalg.solve:", x_solve)

print("\nВсе методы дают одинаковый результат (x1, x2, x3):")
print(f"x1 = {x_solve[0]}, x2 = {x_solve[1]}, x3 = {x_solve[2]}")
# Out:
# Метод Крамера: [650. 325. 525.]
# Матричный метод: [650. 325. 525.]
# np.linalg.solve: [650. 325. 525.]
#
# Все методы дают одинаковый результат (x1, x2, x3):
# x1 = 650.0, x2 = 325.0, x3 = 525.0
